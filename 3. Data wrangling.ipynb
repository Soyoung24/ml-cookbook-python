# %% [markdown]
# 데이터 랭글링은 원본 데이터를 정제하고 사용 가능한 형태로 구성하기 위한 변환 과정을 광범위하게 의미하는 비공식적인 용어

# %%
import pandas as pd

#url = 'https://tinyurl.com/titanic-csv'
# url이 만료된 것 같다. kaggle에서 train 데이터 다운로드 받았음

dataframe = pd.read_csv('data/titanic-train.csv')

dataframe.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 3.1 데이터 프레임 만들기

# %%
dataframe = pd.DataFrame()

# %%
# 열 추가 
dataframe['Name'] = ['JJ', 'SS']
dataframe['Age'] = [38, 24]
dataframe['Driver'] = [True, True]

# %%
dataframe
# Out:
#   Name  Age  Driver
# 0   JJ   38    True
# 1   SS   24    True

# %%
# 새로운 행 추가
new_person = pd.Series(['MM', 40, True],
                      index = ['Name', 'Age', 'Driver'])

# %%
dataframe.append(new_person, ignore_index=True)
# Out:
#   Name  Age  Driver
# 0   JJ   38    True
# 1   SS   24    True
# 2   MM   40    True

# %% [markdown]
# ## 3.3 데이터프레임 탐색하기

# %%
dataframe = pd.read_csv('data/titanic-train.csv')

# 첫번째 행 선택
dataframe.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
dataframe.iloc[1:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# 승객 이름을 인덱스로 설정하고 이름을 사용하여 행 선택

dataframe = dataframe.set_index(dataframe['Name'])

dataframe.loc['Heikkinen, Miss. Laina']
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: Heikkinen, Miss. Laina, dtype: object

# %% [markdown]
# ## 조건에 따라 행 선택하기

# %%
dataframe[dataframe['Sex']=='female'].head(2)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
#
#                                                     Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
#
#                                                                                                  Name  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
#
#                                                        Sex   Age  SibSp  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
# Heikkinen, Miss. Laina                              female  26.0      0
#
# ...

# %%
dataframe[(dataframe['Sex'] == 'female') & (dataframe['Age'] >= 60)]
# Out:
#                                                   PassengerId  Survived  \
# Name
# Andrews, Miss. Kornelia Theodosia                         276         1
# Warren, Mrs. Frank Manley (Anna Sophia Atkinson)          367         1
# Turkula, Mrs. (Hedwig)                                    484         1
# Stone, Mrs. George Nelson (Martha Evelyn)                 830         1
#
#                                                   Pclass  \
# Name
# Andrews, Miss. Kornelia Theodosia                      1
# Warren, Mrs. Frank Manley (Anna Sophia Atkinson)       1
# Turkula, Mrs. (Hedwig)                                 3
# Stone, Mrs. George Nelson (Martha Evelyn)              1
#
#                                                                                               Name  \
# Name
# Andrews, Miss. Kornelia Theodosia                                Andrews, Miss. Kornelia Theodosia
# ...

# %% [markdown]
# ## 3.5 값 치환하기

# %%
dataframe['Sex'].replace('female', "Woman").head(2)
# Out:
# Name
# Braund, Mr. Owen Harris                                 male
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    Woman
# Name: Sex, dtype: object

# %%
dataframe['Sex'].replace(['male','female'], ['Man', "Woman"]).head(5)
# Out:
# Name
# Braund, Mr. Owen Harris                                  Man
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    Woman
# Heikkinen, Miss. Laina                                 Woman
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           Woman
# Allen, Mr. William Henry                                 Man
# Name: Sex, dtype: object

# %%
## 한번에 여러값 바꾸기

dataframe.replace(['female', 'male'], "person").head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %%
dataframe.replace({"female":1, "male":0}).head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %% [markdown]
# ## 3.6 열 이름 바꾸기

# %%
dataframe.rename(columns={'Pclass':'Passenger Class'}).head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Passenger Class  \
# Name
# Braund, Mr. Owen Harris                                           3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...                1
# Heikkinen, Miss. Laina                                            3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                      1
# Allen, Mr. William Henry                                          3
#
# ...

# %% [markdown]
# ## 3.7 최솟값, 최댓값, 합, 평균, 개수 세기

# %%
print('최댓값:', dataframe['Age'].max())
print('최솟값:', dataframe['Age'].min())
print('평균:', dataframe['Age'].mean())
print('합:', dataframe['Age'].sum())
print('카운트:', dataframe['Age'].count())
# Out:
# 최댓값: 80.0
# 최솟값: 0.42
# 평균: 29.69911764705882
# 합: 21205.17
# 카운트: 714

# %%
dataframe.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# ## 3.8 고유한 값 찾기

# %%
dataframe['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
dataframe['Pclass'].nunique()
# Out:
# 3

# %%
dataframe.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ## 3.9 누락된 값 다루기

# %%
dataframe[dataframe['Age'].isnull()].head()
# Out:
#                                PassengerId  Survived  Pclass  \
# Name
# Moran, Mr. James                         6         0       3
# Williams, Mr. Charles Eugene            18         1       2
# Masselmani, Mrs. Fatima                 20         1       3
# Emir, Mr. Farred Chehab                 27         0       3
# O'Dwyer, Miss. Ellen "Nellie"           29         1       3
#
#                                                         Name     Sex  Age  \
# Name
# Moran, Mr. James                            Moran, Mr. James    male  NaN
# Williams, Mr. Charles Eugene    Williams, Mr. Charles Eugene    male  NaN
# Masselmani, Mrs. Fatima              Masselmani, Mrs. Fatima  female  NaN
# Emir, Mr. Farred Chehab              Emir, Mr. Farred Chehab    male  NaN
# O'Dwyer, Miss. Ellen "Nellie"  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#                                SibSp  Parch  Ticket     Fare Cabin Embarked
# Name
# ...

# %% [markdown]
# ## 3.10 열 삭제하기

# %%
dataframe.drop('Age', axis=1).head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %%
dataframe.drop(['Age','Sex'], axis=1).head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %% [markdown]
# ## 3.11 행 삭제하기

# %%
dataframe[dataframe['Sex']!='male'].head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
#
#                                                     Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3
# Nasser, Mrs. Nicholas (Adele Achem)                      2
#
#                                                                                                  Name  \
# Name
# ...

# %% [markdown]
# ## 3.12 중복된 행 삭제하기

# %%
# 모든 열이 완벽히 동일한 행 삭제

dataframe.drop_duplicates().head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %%
# 일부 열만 대상으로 중복된 행을 검사
dataframe.drop_duplicates(subset=['Sex'])
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                               male  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
#
# ...

# %%
dataframe.drop_duplicates(subset=['Sex'], keep = 'last')  # 마지막에 나타난 걸 남겨라
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Dooley, Mr. Patrick                               891         0       3
#
#                                                                               Name  \
# Name
# Johnston, Miss. Catherine Helen "Carrie"  Johnston, Miss. Catherine Helen "Carrie"
# Dooley, Mr. Patrick                                            Dooley, Mr. Patrick
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# Dooley, Mr. Patrick                         male  32.0      0      0
#
#                                               Ticket   Fare Cabin Embarked
# Name
# Johnston, Miss. Catherine Helen "Carrie"  W./C. 6607  23.45   NaN        S
# Dooley, Mr. Patrick                           370376   7.75   NaN        Q

# %% [markdown]
# ## 3.13 Groupby

# %%
dataframe.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
dataframe.groupby('Sex')

# %%
dataframe.groupby('Survived')['Name'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Name, dtype: int64

# %%
dataframe.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %% [markdown]
# ## 3.15 열 원소 순회하기
# 열의 모든 원소에 대하여 어떤 동작 적용하고 싶다.

# %%
for name in dataframe['Name'][0:2]:
    print(name.upper())
# Out:
# BRAUND, MR. OWEN HARRIS
# CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS THAYER)

# %%
[name.upper() for name in dataframe['Name'][0:2]]
# Out:
# ['BRAUND, MR. OWEN HARRIS',
#  'CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS THAYER)']

# %% [markdown]
# ## 3.16 모든 열 원소에 함수 적용하기

# %%
def uppercase(x):
    return x.upper()

# %%
# apply 함수
dataframe['Name'].apply(uppercase)[0:2]
# Out:
# Name
# Braund, Mr. Owen Harris                                                          BRAUND, MR. OWEN HARRIS
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# Name: Name, dtype: object

# %%
# map 함수
dataframe['Survived'].map({1:'Live', 0:'Dead'})[:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                Dead
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    Live
# Heikkinen, Miss. Laina                                 Live
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           Live
# Allen, Mr. William Henry                               Dead
# Name: Survived, dtype: object

# %%
# Age가 30보다 작으면 True
dataframe['Age'].apply(lambda x, age: x < age, age = 30)[:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                 True
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    False
# Heikkinen, Miss. Laina                                  True
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           False
# Allen, Mr. William Henry                               False
# Name: Age, dtype: bool

# %%
dataframe
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass  \
# Name
# ...

# %% [markdown]
# ## 3.17 그룹에 함수 적용하기

# %%
dataframe.groupby('Sex').apply(lambda x: x.count())
# Out:
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Sex
# female          314       314     314   314  314  261    314    314     314
# male            577       577     577   577  577  453    577    577     577
#
#         Fare  Cabin  Embarked
# Sex
# female   314     97       312
# male     577    107       577

# %%
dataframe.groupby('Sex').apply(lambda x: x.mean())
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %% [markdown]
# ## 3.18 데이터프레임 연결하기

# %%
data_a = {'id': ['1', '2', '3'],
          'first': ['Alex', 'Amy', 'Allen'],
          'last': ['Anderson', 'Ackerman', 'Ali']}
dataframe_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])

data_b = {'id': ['4', '5', '6'],
          'first': ['Billy', 'Brian', 'Bran'],
          'last': ['Bonder', 'Black', 'Balwner']}
dataframe_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])

# %%
pd.concat([dataframe_a, dataframe_b], axis = 0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %%
pd.concat([dataframe_a, dataframe_b], axis = 1)
# Out:
#   id  first      last id  first     last
# 0  1   Alex  Anderson  4  Billy   Bonder
# 1  2    Amy  Ackerman  5  Brian    Black
# 2  3  Allen       Ali  6   Bran  Balwner

# %%
row = pd.Series([10, 'Chris', 'Chillon'], index = ['id', 'first', 'last'])

# %%
dataframe_a.append(row, ignore_index=True)
# Out:
#    id  first      last
# 0   1   Alex  Anderson
# 1   2    Amy  Ackerman
# 2   3  Allen       Ali
# 3  10  Chris   Chillon
